# %%
list =[1,22,32,45]
hello = "hello"
print("list = ",list)
print("1 in list =",1 in list)
print("hello in list =",hello in list )
# Out:
# list =  [1, 22, 32, 45]
# 1 in list = True
# hello in list = False

# %%
import keyword
print("the list of \
keyword is :")
print(keyword.kwlist)
# Out:
# the list of keyword is :
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a:str= "amir"
b:str="45"
b=int(b)
print(type(a),type(b))
print(a+str(b))
# Out:
# <class 'str'> <class 'int'>
# amir45

# %% [markdown]
# # **VARIABLE ERROR**

# %%
*uni= "end"
print(*uni)
# Out:
#   File "/tmp/ipython-input-2570861259.py", line 1
#     *uni= "end"
#     ^
# SyntaxError: starred assignment target must be in a list or tuple

# %% [markdown]
# # **Unary number**

# %%
z = 9
y = -z
print("y =", y)
# Out:
# y = -9

# %% [markdown]
# ## **Raw string**

# %%
string:str=r'Hello\t,\n my python'
print(string)
# Out:
# Hello\t,\n my python

# %% [markdown]
# # **Escape sequence character**

# %%
print("Hello,\b World!")
print("Hello,\n World!")
print("Hello,\"wrold!\"")
print("Hello,\\world")
# Out:
#  World!
# Hello,
#  World!
# Hello,"wrold!"
# Hello,\world

# %% [markdown]
# # **Uni code character**

# %%
print(r"\u0095 =","\u0095")
print(r"\u0083 =","\u0083")
print(r"\u0078 =","\u0078")
# Out:
# \u0095 = 
# \u0083 = 
# \u0078 = x

# %% [markdown]
# # **Indexing**

# %%
hello="hello, world"
print(hello[0], hello[5])
# Out:
# h ,

# %% [markdown]
# # **Slicing**

# %%
hello="hello, world"
print(hello[0:6])
# Out:
# hello,

# %% [markdown]
# # **Length**

# %%
hey="Mustafa"
print(len(hey))
# Out:
# 7

# %% [markdown]
# # **Uper case**

# %%
hey="Mustafa"
print(hey.upper())
# Out:
# MUSTAFA

# %% [markdown]
# # **lower Case**

# %%
hey="Mustafa"
print(hey.lower())
# Out:
# mustafa

# %% [markdown]
# # **split methode**

# %%
string: str = 'Hello! World'
words:str=string.split("o")
print(string)
print()
# Out:
# Hello! World
