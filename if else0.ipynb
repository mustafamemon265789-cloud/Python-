# %%
student:int=int(input("Enter your grade:"))
if student > 40:
  print("you are passed")
else:
  print("you are failed")
# Out:
# Enter your grade:45
# you are passed

# %%
num:int=int(input("Enter The Number: "))
if num % 2 == 0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# Enter The Number: 2
# The number is even

# %%
days:list=['sat','sun','mon']
def checkdays(day_num: int):
  if day_num == 1:
    print(f"today is {days[1]}")
  elif day_num == 2:
    print(f"today is {days[2]}")
  elif day_num == 3:
    print(f"today is {days[3]}")
  else:
    print("Invalid day number")
