# %% [markdown]
# # **Python Practice**

# %%
name = input("Enter your name ")
print("Hello,",name)

print("Hope to see you in office soon")
# Out:
# Enter your name Mustafa
# Hello Mustafa
# Hope to see you in office soon

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,2,3,4])
plt.show()

# %% [markdown]
# # **Data Types**

# %% [markdown]
# # **INTEGER**

# %%
x  = 100
type(x)
# Out:
# int

# %% [markdown]
# # **FLOATING NUMBERS**

# %%
x = 3.15*33.1
print(x)
type(x)
# Out:
# 104.265
# float

# %% [markdown]
# # **String**

# %%
x = "Mustafa"
print(x)
type(x)
# Out:
# Mustafa
# str

# %% [markdown]
# # **List**

# %%
x = [13,29,30]
print(x[2])
type(x)
# Out:
# 30
# list

# %%
x[1]= 22
print(x)
# Out:
# [13, 22, 30]

# %% [markdown]
# # **Tuples**
# Tuples are immutable

# %%
x = (12,19,43)
print(x)
type(x)
# Out:
# (12, 19, 43)
# tuple

# %%
print(x[0])
x[2]=33
print(x[2])
# Out:
# 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_213/3710051202.py in <cell line: 0>()
#       1 print(x[0])
# ----> 2 x[2]=33
#       3 print(x[2])
#
# TypeError: 'tuple' object does not support item assignment

# %%
x=y=z = "Mustafa"
print(x,y,z)
# Out:
# Mustafa Mustafa Mustafa

# %%
file = open("variable_com.ipynb", "w") # Open the file first
file.write("Hello World\n")
file.write("Today we learn Python Programming\n") # Added newline for better formatting
lines = ["Line 1: Karachi\n", "Line 2: Lahore\n", "Line 3: Peshawar\n"]
file.writelines(lines)
file.close()

# %%
file = open("variable_com.ipynb","r")
